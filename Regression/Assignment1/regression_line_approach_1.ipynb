# %%
# write a Python code to find the regression line using the theoretical method using Salary_Data.csv. 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Salary_Data.csv')
X = data['YearsExperience']
Y = data['Salary']

# Calculate the means of X and Y
mean_X = np.mean(X)
mean_Y = np.mean(Y)

# Calculate the coefficients m (slope) and c  (intercept)
numerator = np.sum((X - mean_X) * (Y - mean_Y))
denominator = np.sum((X - mean_X) ** 2)
m = numerator / denominator
c = mean_Y - m * mean_X
print(f"Slope (m): {m}")
print(f"Intercept (c): {c}")

# Plot the data points
plt.scatter(X, Y, color='blue', label='Data Points')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Regression Line using Theoretical Method')

# Plot the regression line
regression_line = m * X + c
plt.plot(X, regression_line, color='red', label='Regression Line')
plt.legend()
# Out:
# Slope (m): 9449.962321455077
# Intercept (c): 25792.20019866869
