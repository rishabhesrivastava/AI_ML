# %%
# write a Python code to find the regression line using the theoretical method taught in the class using Salary_Data.csv. 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Salary_Data.csv')
X = data['YearsExperience']
Y = data['Salary']

print("First five rows of the dataset:")
print(data.head()) 
print(X.head())
print(Y.head())
print(data.describe())
print(data.info())
